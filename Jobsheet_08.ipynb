# %% [markdown]
# <a href="https://colab.research.google.com/github/mikhael2104/Algoritma_dan_Pemrograman/blob/main/Jobsheet_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bagian Praktikum**

# %% [markdown]
# # Praktikum 1 - Fungsi Dasar dengan 'def'

# %%
def sapa():
  print("Halo, Selamat datang di Politeknik Negeri Semarang")

sapa()
# Out:
# Halo, Selamat datang di Politeknik Negeri Semarang

# %% [markdown]
# # Praktikum 2 - Fungsi Parameter dan Return

# %%
def tambah(a, b):
  return a + b

hasil = tambah(7, 3)
print("Hasil penjumlahan:", hasil)
# Out:
# Hasil penjumlahan: 10

# %% [markdown]
# # Praktikum 3 - Fungsi dengan Default Argument

# %%
def sapa(nama = "mahasiswa"):
  print(f"Halo, {nama}!")

sapa()
sapa("Andi")
# Out:
# Halo, mahasiswa!
# Halo, Andi!

# %% [markdown]
# # Praktikum 4 - Fungsi dengan *args dan **kwargs

# %%
def jumlahkan(*args):
  return sum(args)

def biodata(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}: {value}")

print("Total:", jumlahkan(1, 2, 3, 4, 5))
biodata(Nama="Budi", Umur=20, Prodi="TRK")
# Out:
# Total: 15
# Nama: Budi
# Umur: 20
# Prodi: TRK

# %% [markdown]
# # Praktikum 5 - Scope Variabel

# %%
x = 10
def ubah():
  x = 5
  print("Nilai Lokal: ", x)

ubah()
print("Nilai Global: ", x)
# Out:
# Nilai Lokal:  5
# Nilai Global:  10

# %% [markdown]
# # Praktikum 6 - Fungsi Lambda

# %%
kali = lambda x, y: x * y
print("Hasil Perkalian: ", kali(4, 5))
# Out:
# Hasil Perkalian:  20

# %% [markdown]
# # Praktikum 7 - Fungsi Decorator

# %%
def decorator_sapa(fungsi):
  def wrapper():
    print("Sebelum fungsi dijalankan....")
    fungsi()
    print("Setelah fungsi dijalankan....")
  return wrapper

@decorator_sapa
def sapa():
  print("Halo, Mahasiswa Polines!")

sapa()
# Out:
# Sebelum fungsi dijalankan....
# Halo, Mahasiswa Polines!
# Setelah fungsi dijalankan....

# %% [markdown]
# # Praktikum 8 - Studi Kasus: Menghitung Rata-rata Nilai Mahasiswa

# %%
def hitung_rata(data):
  return sum(data)/len(data)

nilai = [80, 90, 85]
rata = hitung_rata(nilai)

print("Rata-rata nilai: ", rata)
# Out:
# Rata-rata nilai:  85.0

# %% [markdown]
# # **Bagian Penugasan**

# %% [markdown]
# # Penugasan 3 - Fungsi Sederhana

# %%
def perkenalan(Nama, Prodi):
  print(f"Halo, nama saya {Nama}, saya dari prodi {Prodi}")

perkenalan("Mikhael Surya", "TRK")
perkenalan("Albertus Satrio", "Akutansi")
perkenalan("Vanessa", "Telekomunikasi")
# Out:
# Halo, nama saya Mikhael Surya, saya dari prodi TRK
# Halo, nama saya Albertus Satrio, saya dari prodi Akutansi
# Halo, nama saya Vanessa, saya dari prodi Telekomunikasi

# %% [markdown]
# # Penugasan 4 - Fungsi dengan Parameter dan Return

# %%
def luas_persegi(panjang, lebar):
  return panjang * lebar

print("luas persegi panjang: ", luas_persegi(4, 5))
print("luas persegi panjang: ", luas_persegi(5, 6))
print("luas persegi panjang: ", luas_persegi(10, 9))
# Out:
# luas persegi panjang:  20
# luas persegi panjang:  30
# luas persegi panjang:  90

# %% [markdown]
# # Penugasan 5 - Fungsi dengan Default Argument

# %%
def salam(waktu="pagi", nama="mahasiswa"):
  print(f"Selamat {waktu}, {nama}!")

salam("siang", "mikhael")
salam("malam")
salam(nama = "Ozora")
salam()
# Out:
# Selamat siang, mikhael!
# Selamat malam, mahasiswa!
# Selamat pagi, Ozora!
# Selamat pagi, mahasiswa!

# %% [markdown]
# # Penugasan 6 - Fungsi dengan *Args

# %%
def jumlahkan_semua(*angka):
  return sum(angka)

print("Total:", jumlahkan_semua(3, 5, 7))
# Out:
# Total: 15

# %% [markdown]
# # Penugasan 7 - Fungsi dengan Kwargs

# %%
def info_barang(**data):
  for key, value in data.items():
    print(f"{key}: {value}")

info_barang(Nama = "Buku", Harga = "15000", Stok = "30")
# Out:
# Nama: Buku
# Harga: 15000
# Stok: 30

# %% [markdown]
# # Penugasan 8 - Scope Variabel

# %%
x = 100

def ubah():
  x = 50
  print("X adalah: ", x)

ubah()
print("X adalah: ", x)
# Out:
# X adalah:  50
# X adalah:  100

# %% [markdown]
# # Penugasan 9 - Fungsi Lambda

# %%
kuadrat = lambda x: x**2
print("Hasil kuadrat: ", kuadrat(6))
# Out:
# Hasil kuadrat:  36

# %%
k_lingkaran = lambda r: 2 * r * 3.14
print("Keliling lingkaran: ", k_lingkaran(7))
# Out:
# Keliling lingkaran:  43.96

# %% [markdown]
# # Penugasan 10 - Fungsi Decorator

# %%
def logger(fungsi):
  def wrapper():
    print("Memulai Fungsi...")
    fungsi()
    print("Fungsi selesai dijalankan")
  return wrapper

@logger
def halo():
  print("Halo, Selamat Pagi Sayang")

halo()
# Out:
# Memulai Fungsi...
# Halo, Selamat Pagi Sayang
# Fungsi selesai dijalankan

# %% [markdown]
# # Penugasan 11 - Studi Kasus Nyata: Program Nilai

# %% [markdown]
# Buat program sederhana yang terdiri dari beberapa fungsi:
# a.	input_nilai() untuk menerima nilai mahasiswa (list).
# b.	hitung_rata() untuk menghitung rata-rata nilai.
# c.	status_kelulusan(rata) untuk menentukan apakah mahasiswa lulus (≥ 60) atau tidak.
# d.	Tambahkan lambda untuk menghitung nilai akhir berdasarkan bobot (misalnya 40% tugas, 60% ujian).

# %%
def input_nilai():
  return int(input("Masukkan nilai mahasiswa: "))

def hitung_rata(nilai):
  return sum(nilai)/len(nilai)

rata = hitung_rata(nilai)

print("Rata-rata nilai: ", rata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2231780446.py in <cell line: 0>()
#       5   return sum(nilai)/len(nilai)
#       6
# ----> 7 rata = hitung_rata(nilai)
#       8
#       9 print("Rata-rata nilai: ", rata)
#
# NameError: name 'nilai' is not defined
