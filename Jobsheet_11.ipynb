# %% [markdown]
# <a href="https://colab.research.google.com/github/mikhael2104/Algoritma_dan_Pemrograman/blob/main/Jobsheet_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bagian Praktikum**

# %% [markdown]
# # Praktikum 1 - Sequential Search pada Data Angka

# %%
def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i}"

# %% [markdown]
# # Praktikum 2 - Binary Search pada Data Angka

# %% [markdown]
# # Praktikum 3 - Sequantial Search untuk Data Nama
